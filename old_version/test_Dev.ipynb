# %%
from TOVdev import *
import matplotlib 
import matplotlib.pyplot as plt
import scipy.constants as cst
import numpy as np

from tqdm import tqdm

from lal import  C_SI, HBAR_SI, H_SI, G_SI, MSUN_SI
M_sun = MSUN_SI

import pickle
import os

# %%
def find_dilaton_center(density, option, precision, radiusStep):
    rhoInit = density*cst.eV*10**6/(cst.c**2*cst.fermi**3)
#     radiusStep = 100
    PsiInit = 0
    radiusInit = 0.000001
    dilaton = True
    
    #Find limits of potential Phi_0
    Phi0_min, Phi0_max = 0.5, 1.5 # initial limits
    
    tov_min = TOV(radiusInit, rhoInit, PsiInit, Phi0_min, radiusStep, option, dilaton)
    tov_min.Compute()
    Phi_inf_min = tov_min.Phi[-1]
    while Phi_inf_min > 1:
        Phi0_min -= 0.1
        if Phi0_min == 0:
            Phi0_min = 1e-2
#             print(f'Had to put l.h.s. limit of $\Phi_0$ to {Phi0_min}')
        tov_min = TOV(radiusInit, rhoInit, PsiInit, Phi0_min, radiusStep, option, dilaton)
        tov_min.Compute()
        Phi_inf_min = tov_min.Phi[-1]
#         print(f'Had to lower down the l.h.s.limit of $\Phi_0$ to {Phi0_min:.1f}')
        
    tov_max = TOV(radiusInit, rhoInit, PsiInit, Phi0_max, radiusStep, option, dilaton)
    tov_max.Compute()
    Phi_inf_max = tov_max.Phi[-1]
    while Phi_inf_max <1:
        Phi0_max += 0.1
        tov_max = TOV(radiusInit, rhoInit, PsiInit, Phi0_max, radiusStep, option, dilaton)
        tov_max.Compute()
        Phi_inf_max = tov_max.Phi[-1]
#         print(f'Had to increase the r.h.s. limit of $\Phi_0$ to {Phi0_max:.1f}')
        
    #Search for Phi_0 that leads to Phi_inf = 1 to a given precision by dichotomy
    step_precision = 1
    Phi0_dicho = np.array([Phi0_min, (Phi0_min + Phi0_max) / 2, Phi0_max])
    Phi_inf_dicho = np.zeros(3)
    #print(len(Phi0_dicho),len(Phi_inf_dicho))
    while step_precision > precision:
        for n in range(3):
            #print(Phi0_dicho[n])
            tov = TOV(radiusInit, rhoInit, PsiInit, Phi0_dicho[n], radiusStep, option, dilaton)
            tov.Compute()
            Phi_inf_dicho[n] = tov.Phi[-1]
            #print(Phi_inf_dicho[n])
        #print(Phi_inf_dicho)    
        N = np.min(np.argwhere(Phi_inf_dicho>1))
        
        Phi0_min = Phi0_dicho[N-1]
        Phi0_max = Phi0_dicho[N]
        Phi0_dicho = [Phi0_min, (Phi0_min + Phi0_max) / 2, Phi0_max]
        
        
        step_precision = np.abs(Phi_inf_dicho[N] - Phi_inf_dicho[N-1])
        
        
    return (Phi0_min + Phi0_max) / 2, (Phi0_min - Phi0_max) / 2, (Phi_inf_dicho[N] + Phi_inf_dicho[N-1]) / 2

# %%
find_dilaton_center(100., 1, 1e-2, 10)[0]
# Out:
# /home/olivier/ownCloud/travail/articles/TOV_entangled_gravity/code/git_fork_rousselle/dev/TOVdev.py:18: RuntimeWarning: invalid value encountered in double_scalars
#   return (P/k)**(3/5)
# 0.99609375

# %%
def test_dilaton(density, option, precision, radiusStep):
    rhoInit = density*cst.eV*10**6/(cst.c**2*cst.fermi**3)
#     radiusStep = 100
    PsiInit = 0
    if option == 1:
        PhiInit = find_dilaton_center(density, option, precision, radiusStep)[0]
    else:
        PhiInit = 1.
    radiusInit = 0.000001
    #option = 1
    dilaton = False
    tov = TOV(radiusInit, rhoInit, PsiInit, PhiInit, radiusStep, option, dilaton)
    tov.Compute()
#     tov.PlotGttGrr()
#     tov.PlotGrroverGtt()
    tov.plot_speedOFsound()
    dilaton = True
    tov = TOV(radiusInit, rhoInit, PsiInit, PhiInit, radiusStep, option, dilaton)
    tov.Compute()
#     tov.PlotGttGrr()
#     tov.PlotGrroverGtt()
    tov.plot_speedOFsound()
#     print(f'radius = {tov.radiusStar/1e3:.1f} km')
#     print(f'mass = {tov.massStar / M_sun} solar masses')
#     print(f'Pressure = {tov.pressureStar}')
#     print(f'Pressure at center = {tov.initPressure}')
#     print(f'Phi = {tov.Phi[-1]}')

# %%
precision = 0.001
pas = 10
density_min = 20000
density_max = 30000
nb_points = 100

#GRvsER = plotGRvsER(0., 1, precision, pas, density_min, density_max, nb_points)

# %% [raw]
# test_dilaton(10000, 1, precision, pas)

# %%
for dens in tqdm(range(100,10001,100)):
    test_dilaton(dens, 1, precision, pas)
# Out:
# ...
# 100%|██████████| 100/100 [11:40<00:00,  6.97s/it]

# %%
# faire plots jusqu'à 40 000 ~ 1 heure

# %% [raw]
# def plotGRvsER(PsiInit, option, precision,radiusStep, rhoMin, rhoMax, Nbr_points):
# #     radiusStep = 100
#     #rhoMin = 100
#     #rhoMax = 5000
#     #rhoMax = 10000
#     radiusInit = 0.000001
#
#     massStar_ER = []
#     radiusStar_ER = []
#     massStar_GR = []
#     radiusStar_GR = []
#     Phi0 = []
# #     rho = [x*cst.eV*10**6/(cst.c**2*cst.fermi**3) for x in range(rhoMin,rhoMax,rhoStep)]
#     rho = [x*cst.eV*10**6/(cst.c**2*cst.fermi**3) for x in np.linspace(start = rhoMin,stop = rhoMax, num = Nbr_points)]
#
#     for iRho in tqdm(rho):
#         rhoInit = iRho
#         # Computation in ER
#         PhiInit = find_dilaton_center(iRho/(cst.eV*10**6/(cst.c**2*cst.fermi**3)), option, precision, radiusStep)[0]
#         Phi0.append(PhiInit)
#         tov = TOV(radiusInit, rhoInit, PsiInit, PhiInit, radiusStep, option, True)
#         tov.Compute()
#         massStar_ER.append(tov.massStar)
#         radiusStar_ER.append(tov.radiusStar)
#         # Computation in GR
#         tov = TOV(radiusInit, rhoInit, PsiInit, PhiInit, radiusStep, option, False)
#         tov.Compute()
#         massStar_GR.append(tov.massStar)
#         radiusStar_GR.append(tov.radiusStar)
#     if option == 0:
#         lagrangianLabel = 'T'
#     elif option == 1:
#         lagrangianLabel = '$-\\rho c^2$'
#     elif option == 2:
#         lagrangianLabel = 'P'
#     else:
#         print('not a valid option')
#
#     fig = plt.figure(figsize=(8, 6))
#     plt.subplot(221)
#     plt.plot([x/(cst.eV*10**6/(cst.c**2*cst.fermi**3)) for x in rho], [x/M_sun for x in massStar_ER], label='ER')
#     plt.plot([x/(cst.eV*10**6/(cst.c**2*cst.fermi**3)) for x in rho], [x/M_sun for x in massStar_GR], label='GR')
#     plt.ylabel('Mass $M/M_{\odot}$')
#     plt.legend()
#
#     plt.subplot(222)
#     plt.plot([x/1000 for x in radiusStar_ER], [x/M_sun for x in massStar_ER], label='ER')
#     plt.plot([x/1000 for x in radiusStar_GR], [x/M_sun for x in massStar_GR], label='GR')
#     plt.xlabel('Radius R (km)')
#     plt.legend()
#
#     plt.subplot(223)
#     plt.plot([x/(cst.eV*10**6/(cst.c**2*cst.fermi**3)) for x in rho], [x/1000 for x in radiusStar_ER], label='ER')
#     plt.plot([x/(cst.eV*10**6/(cst.c**2*cst.fermi**3)) for x in rho], [x/1000 for x in radiusStar_GR], label='GR')
#     plt.xlabel('Density $\\rho$ ($Mev/fm^3$)')
#     plt.ylabel('Radius R (km)')
#     plt.legend()
#
#     plt.subplot(224)
#     plt.plot([x/(cst.eV*10**6/(cst.c**2*cst.fermi**3)) for x in rho], Phi0, color = 'blue', label='$\Phi_0$')
#     plt.xlabel('Density $\\rho$ ($Mev/fm^3$)')
#     plt.legend()
#
#     # Save figure
#     plt.savefig(f'Fig_GRvsER_{radiusStep}_{rhoMin}_{rhoMax}_{Nbr_points}.png', dpi = 200)
#
#     X = [[x/(cst.eV*10**6/(cst.c**2*cst.fermi**3)) for x in rho], [x/1000 for x in radiusStar_GR], [x/M_sun for x in massStar_GR], [x/1000 for x in radiusStar_ER], [x/M_sun for x in massStar_ER], Phi0, lagrangianLabel ]
#
#     # Save data in file
#     with open(f'GRvsER_{radiusStep}_{rhoMin}_{rhoMax}_{Nbr_points}.dat', "wb") as fp:
#         pickle.dump(X, fp)
# #     return [x/(cst.eV*10**6/(cst.c**2*cst.fermi**3)) for x in rho], [x/1000 for x in radiusStar_GR], [x/M_sun for x in massStar_GR], [x/1000 for x in radiusStar_ER], [x/M_sun for x in massStar_ER], Phi0, lagrangianLabel
#     return X

# %% [raw]
# # Below: recovering already computed data and figures

# %% [raw]
# # List all data files (for which a figure has been created)
# prefixed = [filename for filename in os.listdir('.') if filename.startswith('Fig_GRvsER')]
#
# for i in prefixed:
#     name_decomp = i.split('.')[0].split('_')
#     data_file_name = f'GRvsER_{name_decomp[2]}_{name_decomp[3]}_{name_decomp[4]}_{name_decomp[5]}.dat'
#     print(data_file_name)

# %% [raw]
# #Replot all figures from data (for which a figure has been created)
#
# for i in prefixed:
#     name_decomp = i.split('.')[0].split('_')
#     data_file_name = f'GRvsER_{name_decomp[2]}_{name_decomp[3]}_{name_decomp[4]}_{name_decomp[5]}.dat'
# #     print(data_file_name)
#     with open(f'{data_file_name}', "rb") as fp:
#         b = pickle.load(fp)
#
#     #Plot
#     fig = plt.figure(figsize=(8, 6))
#     plt.subplot(221)
#     plt.plot(b[0],b[3], label='ER')
#     plt.plot(b[0], b[1], label='GR')
#     plt.ylabel('Mass $M/M_{\odot}$')
#     plt.legend()
#
#
#     plt.subplot(222)
#     plt.plot(b[3], b[4], label='ER')
#     plt.plot(b[1], b[2], label='GR')
#     plt.xlabel('Radius R (km)')
#     plt.legend()
#
#     plt.subplot(223)
#     plt.plot(b[0], b[4], label='ER')
#     plt.plot(b[0], b[2], label='GR')
#     plt.xlabel('Density $\\rho$ ($Mev/fm^3$)')
#     plt.ylabel('Radius R (km)')
#     plt.legend()
#
#     plt.subplot(224)
#     plt.plot(b[0], b[5], color = 'blue', label='$\Phi_0$')
#     plt.xlabel('Density $\\rho$ ($Mev/fm^3$)')
#     plt.legend()
